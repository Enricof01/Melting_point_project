# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split

import os
# Keep using Keras 2
os.environ['TF_USE_LEGACY_KERAS'] = '1'

# %%
#Preprocessing

df = pd.read_csv("../Melting_point_project/melting-point-data/Train_3d_features.csv")
# df = df.drop(["Unnamed: 0"], axis = 1)

# df = df.drop(columns = df.filter(regex = "Group").columns)

y = np.array(df["Tm"])

X = np.array(df.drop(["Tm"], axis = 1))



X_train, X_test, y_train, y_test = train_test_split(
     X, y, test_size=0.33, random_state=42)

# %%
label = "Tm"
df.columns
# Out:
# Index(['Unnamed: 0', 'id', 'SMILES', 'Tm', 'Group 1', 'Group 2', 'Group 3',
#        'Group 4', 'Group 5', 'Group 6',
#        ...
#        'Group 422', 'Group 423', 'Group 424', 'MolWeight', 'NPR1', 'NPR2',
#        'Asphericity', 'Eccentricity', 'InertialShapeFactor',
#        'RadiusOfGyration'],
#       dtype='object', length=435)

# %%
import pandas as pd
import numpy as np
from lightgbm import LGBMRegressor
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_error

# Daten laden
df = pd.read_csv("../Melting_point_project/melting-point-data/train_newFeature.csv")
df = df.drop(["Unnamed: 0", "id", "SMILES"], axis=1)

X = df.drop("Tm", axis=1).values
y = df["Tm"].values

X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.33, random_state=42
)

# LightGBM-Regressor
model = LGBMRegressor(
    n_estimators=500,
    learning_rate=0.01,
    num_leaves=500,
    max_depth=-1,
    subsample=0.8,
    colsample_bytree=0.8,
    random_state=42,
    n_jobs=-1
)

model.fit(X_train, y_train)

# Evaluation
y_pred = model.predict(X_test)
mae = mean_absolute_error(y_test, y_pred)

print("MAE:", mae)
# Out:
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.002560 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 580
# [LightGBM] [Info] Number of data points in the train set: 1783, number of used features: 75
# [LightGBM] [Info] Start training from score 278.558392
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# ...
